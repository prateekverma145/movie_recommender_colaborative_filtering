# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rat=pd.read_csv('ratings.csv')

# %%
rat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   userId   int64
#  1   movieId  int64
#  2   rating   float64
# dtypes: float64(1), int64(2)
# memory usage: 595.6 MB

# %%
t=rat.groupby('userId').mean()['rating'].reset_index()

# %%
f_users=t[t['rating']>500]

# %%
f_users.rename(columns={'rating':'num_rating'},inplace=True)
# Out:
# C:\Users\prateek\AppData\Local\Temp\ipykernel_1168\2163830920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_users.rename(columns={'rating':'num_rating'},inplace=True)

# %%
f_users
# Out:
#       userId  num_rating    rating
# 0         24         634  3.474763
# 1         46         766  3.210836
# 2        120         516  3.488372
# 3        132         572  3.375874
# 4        150         585  3.167521
# ...      ...         ...       ...
# 9447  270654        2297  3.489334
# 9448  270684         729  3.205761
# 9449  270734         733  3.881310
# 9450  270769         733  3.297408
# 9451  270887        2501  3.644142
#
# [9452 rows x 3 columns]

# %%
f_users=f_users.merge(t,on='userId')

# %%
rating_with_users=rat[rat['userId'].isin(f_users['userId'])]

# %%
rating_with_users=rating_with_users.reset_index(drop=True)

# %%
rating_with_users
# Out:
#          userId  movieId  rating
# 0            24        1     4.0
# 1            24        2     3.0
# 2            24        6     4.0
# 3            24       16     3.0
# 4            24       17     3.0
# ...         ...      ...     ...
# 8543114  270887   171439     1.0
# 8543115  270887   171755     3.0
# 8543116  270887   173149     5.0
# 8543117  270887   173405     5.0
# 8543118  270887   174473     5.0
#
# [8543119 rows x 3 columns]

# %% [markdown]
# ## working on popular movies

# %%
df=pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\prateek\AppData\Local\Temp\ipykernel_1168\2212646091.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('movies_metadata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
columns_to_select = ['id', 'title', 'original_language', 'vote_average', 'vote_count','popularity','poster_path']
selected_columns_df = df[columns_to_select]

# %%
selected_columns_df['popularity']=pd.to_numeric(selected_columns_df['popularity'],errors='coerce')
# Out:
# C:\Users\prateek\AppData\Local\Temp\ipykernel_1168\1096959785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns_df['popularity']=pd.to_numeric(selected_columns_df['popularity'],errors='coerce')

# %%
sc_df=selected_columns_df[(selected_columns_df['popularity']>12) & (selected_columns_df['vote_count']>50)].reset_index().sort_values('vote_count',ascending=False)

# %%
sc_df.drop('index',axis=1,inplace=True)

# %%
sc_df['movieId']=pd.to_numeric(sc_df['movieId'],errors='coerce')

# %%
sc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1608 entries, 0 to 1607
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movieId            1608 non-null   int64
#  1   title              1608 non-null   object
#  2   original_language  1608 non-null   object
#  3   vote_average       1608 non-null   float64
#  4   vote_count         1608 non-null   float64
#  5   popularity         1608 non-null   float64
#  6   poster_path        1608 non-null   object
#  7   id                 1608 non-null   int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 100.6+ KB

# %%
sc_df.rename(columns={'id':'movieId'},inplace=True)

# %%
sc_df.reset_index(inplace=True,drop=True)

# %%
pp=sc_df.head(50)

# %%
pp.to_csv('popular_movies.csv',index=False)

# %%
rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41894 entries, 17 to 8540742
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   userId   41894 non-null  int64
#  1   movieId  41894 non-null  int64
#  2   rating   41894 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.3 MB

# %%
rf
# Out:
#          userId  movieId  rating
# 17           24       58     5.0
# 81           24      550     2.0
# 93           24      597     3.0
# 640          46       24     3.0
# 652          46      105     1.5
# ...         ...      ...     ...
# 8540642  270887      105     5.0
# 8540718  270887      539     5.0
# 8540731  270887      597     5.0
# 8540735  270887      637     3.0
# 8540742  270887      673     1.0
#
# [41894 rows x 3 columns]

# %%
sc_df.nunique()
# Out:
# movieId              1607
# title                1583
# original_language      18
# vote_average           46
# vote_count           1185
# popularity           1607
# poster_path          1607
# id                   1607
# dtype: int64

# %%
data=sc_df.merge(rf,on='movieId')

# %%
pt=data.pivot_table(columns='userId',index='title',values='rating')

# %%
pt
# Out:
# userId                                              24      46      120     \
# title
# Ant-Man                                                NaN     NaN     NaN
# Avengers: Age of Ultron                                NaN     NaN     NaN
# Back to the Future                                     NaN     1.5     NaN
# Batman Begins                                          NaN     NaN     4.0
# Blade Runner                                           NaN     NaN     NaN
# Dawn of the Planet of the Apes                         NaN     NaN     NaN
# Fight Club                                             2.0     3.0     NaN
# Finding Nemo                                           NaN     NaN     NaN
# Forrest Gump                                           NaN     NaN     NaN
# Guardians of the Galaxy                                NaN     NaN     NaN
# Harry Potter and the Chamber of Secrets                NaN     NaN     NaN
# ...

# %%
import pickle
pickle.dump(pt,open('pt.pkl','wb'))

# %%
from sklearn.metrics.pairwise import cosine_similarity
simi=cosine_similarity(pt.fillna(0))

# %%
import pickle
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(simi,open('simi.pkl','wb'))

# %%
def recommend(movie):
    index=np.where(pt.index==movie)[0][0]
    s=sorted(list(enumerate(simi[index])),key=lambda x:x[1],reverse=True)[1:6]
   
    for i in s:
        print(pt.index[i[0]])

# %%
recommend('The Hunger Games: Mockingjay - Part 2')
# Out:
# Schindler's List
# Twilight
# The Lord of the Rings: The Return of the King
# Harry Potter and the Prisoner of Azkaban
# Monsters, Inc.

# %%
f=pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\prateek\AppData\Local\Temp\ipykernel_1708\2551636135.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   f=pd.read_csv('movies_metadata.csv')

# %%
f=f[['title','id']]

# %%
r.to_csv('movie_name_id.csv',index=False)

# %%
t=pd.to_numeric(f['id'],errors='coerce')

# %%
f['id']=t
# Out:
# C:\Users\prateek\AppData\Local\Temp\ipykernel_1708\3769735715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['id']=t

# %%
int(f[f['title']=='Inception']['id'].values[0])
# Out:
# 27205

# %%
r=pd.read_csv('movie_name_id.csv')

# %%
r
# Out:
#                              title      id
# 0                        Toy Story     862
# 1                          Jumanji    8844
# 2                 Grumpier Old Men   15602
# 3                Waiting to Exhale   31357
# 4      Father of the Bride Part II   11862
# ...                            ...     ...
# 45461                       Subdue  439050
# 45462          Century of Birthing  111109
# 45463                     Betrayal   67758
# 45464             Satan Triumphant  227506
# 45465                     Queerama  461257
#
# [45466 rows x 2 columns]

# %%
import pickle
pt=pickle.load(open('pt.pkl','rb'))

# %%
pt.index
# Out:
# Index(['Ant-Man', 'Avengers: Age of Ultron', 'Back to the Future',
#        'Batman Begins', 'Blade Runner', 'Dawn of the Planet of the Apes',
#        'Fight Club', 'Finding Nemo', 'Forrest Gump', 'Guardians of the Galaxy',
#        'Harry Potter and the Chamber of Secrets',
#        'Harry Potter and the Philosopher's Stone',
#        'Harry Potter and the Prisoner of Azkaban', 'Inception', 'Interstellar',
#        'Kill Bill: Vol. 1', 'Life Is Beautiful', 'Monsters, Inc.',
#        'Once Upon a Time in America', 'One Flew Over the Cuckoo's Nest',
#        'Pan's Labyrinth', 'Pirates of the Caribbean: At World's End',
#        'Pirates of the Caribbean: Dead Man's Chest',
#        'Pirates of the Caribbean: On Stranger Tides',
#        'Pirates of the Caribbean: The Curse of the Black Pearl', 'Psycho',
#        'Pulp Fiction', 'Schindler's List', 'Spider-Man 3', 'Spirited Away',
#        'Star Wars', 'The Amazing Spider-Man', 'The Dark Knight',
# ...

# %%
int(r[r['title']=='Jumanji']['id'].values[0])
# Out:
# 8844
